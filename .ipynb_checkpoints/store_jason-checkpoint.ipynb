# %%
import simplejson
import json

# %%
with open('gentle.json') as json_file:
    data = json.load(json_file)

# %%
file = open('gentle.json')

# %%
ds = json.load(file)

# %%
print(ds['words'][0])
# Out:
# [{'alignedWord': 'um', 'case': 'success', 'end': 1.04, 'endOffset': 2, 'phones': [{'duration': 0.45, 'phone': 'ah_B'}, {'duration': 0.22, 'phone': 'm_E'}], 'start': 0.37, 'startOffset': 0, 'word': 'Um'}, {'alignedWord': 'really', 'case': 'success', 'end': 2.29, 'endOffset': 10, 'phones': [{'duration': 0.14, 'phone': 'r_B'}, {'duration': 0.21, 'phone': 'iy_I'}, {'duration': 0.1, 'phone': 'l_I'}, {'duration': 0.41, 'phone': 'iy_E'}], 'start': 1.4300000000000002, 'startOffset': 4, 'word': 'really'}, {'case': 'not-found-in-transcript', 'end': 2.3499999999999996, 'phones': [{'duration': 0.01, 'phone': 'ah_S'}], 'start': 2.34, 'word': 'uh'}, {'alignedWord': 'last', 'case': 'success', 'end': 3.06, 'endOffset': 16, 'phones': [{'duration': 0.14, 'phone': 'l_B'}, {'duration': 0.24, 'phone': 'ao_I'}, {'duration': 0.15, 'phone': 's_I'}, {'duration': 0.07, 'phone': 't_E'}], 'start': 2.46, 'startOffset': 12, 'word': 'last'}, {'alignedWord': 'holiday', 'case': 'success', 'end': 4.0, 'endOffset': 25
# ...

# %%
with open('gentle.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-72e45fc26092> in <module>
#       1 import json
#       2 with open('gentle.json', 'w', encoding='utf-8') as f:
# ----> 3     json.dump(data, f, ensure_ascii=False, indent=4)
#
# NameError: name 'data' is not defined
