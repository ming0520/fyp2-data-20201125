# %%
import simplejson
import json

# %%
with open('gentle.json') as json_file:
    data = json.load(json_file)

# %%
file = open('gentle.json')

# %%
ds = json.load(file)

# %%
for p in data['words']:
#     print('case: ' + p['case'], end =" ")
    if(p['case'] == 'success'):
        print('alignedWord: '+ p['alignedWord'], end = " ")
        print('start: '+ str(p['start']), end = " ")
        print('end: '+ str(p['end']), end = " ")
#     print('Website: ' + p['website'])
#     print('From: ' + p['from'])
    print('')
# Out:
# alignedWord: um start: 0.37 end: 1.04
# alignedWord: really start: 1.4300000000000002 end: 2.29
#
# alignedWord: last start: 2.46 end: 3.06
# alignedWord: holiday start: 3.07 end: 4.0
# alignedWord: i start: 4.17 end: 4.26
# alignedWord: went start: 4.26 end: 4.58
# alignedWord: to start: 5.07 end: 5.260000000000001
# alignedWord: america start: 5.26 end: 5.84
#
#
# alignedWord: see start: 6.09 end: 6.3
# alignedWord: my start: 6.3 end: 6.51
# alignedWord: auntie start: 6.93 end: 7.33
# alignedWord: and start: 7.33 end: 7.44
# alignedWord: uncle start: 7.44 end: 8.07
# alignedWord: and start: 9.21 end: 9.63
# alignedWord: um start: 9.66 end: 10.07
# alignedWord: she start: 11.52 end: 11.799999999999999
# alignedWord: has start: 11.8 end: 12.290000000000001
# alignedWord: a start: 12.62 end: 12.729999999999999
# alignedWord: cat start: 12.73 end: 13.22
#
#
# alignedWord: dogs start: 13.94 end: 14.66
# alignedWord: it start: 14.849999 end: 15.009999
# ...

# %%
with open('output.json', 'w', encoding='utf-8') as f:
    json.dump(ds, f, ensure_ascii=False, indent=4)
